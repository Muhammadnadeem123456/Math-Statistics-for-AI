# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("basic_statistic.csv", names=["names", "income"], skiprows=[0])
df
# Out:
#    names   incomes
# 0    Rob      5000
# 1  Rafiq      6000
# 2   Nina      4000
# 3  Sofia      7500
# 4  mohan      8000
# 5    tao      7000
# 6   Elon  10000000

# %%
df.describe()
# Out:
#             incomes
# count  7.000000e+00
# mean   1.433929e+06
# std    3.777283e+06
# min    4.000000e+03
# 25%    5.500000e+03
# 50%    7.000000e+03
# 75%    7.750000e+03
# max    1.000000e+07

# %%
df.incomes.quantile(0.75)
# Out:
# np.float64(7750.0)

# %%
print(df.columns)
# Out:
# Index(['names', 'incomes'], dtype='object')

# %%
df.columns
# Out:
# Index(['names', 'incomes'], dtype='object')

# %%
df.incomes.quantile(0.45)
# Out:
# np.float64(6700.0)

# %%
df.incomes.quantile(0.25)
# Out:
# np.float64(5500.0)

# %%
df.incomes.quantile(1)
# Out:
# np.float64(10000000.0)

# %%
perentile_99=df.incomes.quantile(0.99)
print(perentile_99)
# Out:
# 9400479.999999994

# %%
print(df.incomes>perentile_99)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# Name: incomes, dtype: bool

# %%
[df.incomes > perentile_99]
# Out:
# [0    False
#  1    False
#  2    False
#  3    False
#  4    False
#  5    False
#  6     True
#  Name: incomes, dtype: bool]

# %% [markdown]
# # Handling outlier

# %%
no_outlier=df[df.incomes <= perentile_99]

# %%
print(no_outlier)
# Out:
#    names  incomes
# 0    Rob     5000
# 1  Rafiq     6000
# 2   Nina     4000
# 3  Sofia     7500
# 4  mohan     8000
# 5    tao     7000

# %% [markdown]
# # Filling missing values

# %%
df
# Out:
#    names   incomes
# 0    Rob      5000
# 1  Rafiq      6000
# 2   Nina      4000
# 3  Sofia      7500
# 4  mohan      8000
# 5    tao      7000
# 6   Elon  10000000

# %%
df['incomes'][3] = np.nan

# %%
df
# Out:
#    names     incomes
# 0    Rob      5000.0
# 1  Rafiq      6000.0
# 2   Nina      4000.0
# 3  Sofia         NaN
# 4  mohan      8000.0
# 5    tao      7000.0
# 6   Elon  10000000.0

# %%
new_df=df.fillna(df.incomes.mean())
new_df
# Out:
#    names       incomes
# 0    Rob  5.000000e+03
# 1  Rafiq  6.000000e+03
# 2   Nina  4.000000e+03
# 3  Sofia  1.671667e+06
# 4  mohan  8.000000e+03
# 5    tao  7.000000e+03
# 6   Elon  1.000000e+07

# %% [markdown]
# # Now handling Outliers

# %%
new_df=df.fillna(df.incomes.median())
new_df
# Out:
#    names     incomes
# 0    Rob      5000.0
# 1  Rafiq      6000.0
# 2   Nina      4000.0
# 3  Sofia      6500.0
# 4  mohan      8000.0
# 5    tao      7000.0
# 6   Elon  10000000.0

# %% [markdown]
# # About Dataset

# %% [markdown]
# # Context
# # Since 2008, guests and hosts have used Airbnb to expand on traveling possibilities and present more unique, personalized way of experiencing the world. This dataset describes the listing activity and metrics in NYC, NY for 2019.

# %% [markdown]
# # Content
# # This data file includes all needed information to find out more about hosts, geographical availability, necessary metrics to make predictions and draw conclusions.

# %% [markdown]
# # Acknowledgements
# # This public dataset is part of Airbnb, and the original source can be found on this website.

# %%
import pandas as pd

# %%
df = pd.read_csv("AB_NYC_2019.csv")
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.price.describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
min_thresold, max_thresold = df.price.quantile([0.01,0.999])
min_thresold, max_thresold
# Out:
# (30.0, 3000.0)

# %%
df[df.price<min_thresold]
# Out:
#              id                                             name    host_id  \
# 957      375249                  Enjoy Staten Island Hospitality    1887999
# 2675    1428154              Central, Peaceful Semi-Private Room    5912572
# 2860    1620248    Large furnished 2 bedrooms- - 30 days Minimum    2196224
# 3020    1767037               Small Cozy Room Wifi & AC near JFK    9284163
# 3918    2431607                    Bright, Airy Room Share for 2    4973668
# ...         ...                                              ...        ...
# 48486  36280646                     Cable and wfi, L/G included.  272872092
# 48647  36354776    Cozy bedroom in diverse neighborhood near JFK  273393150
# 48832  36450814                         FLATBUSH HANG OUT AND GO  267223765
# 48867  36473044  The place you were dreaming for.(only for guys)  261338177
# 48868  36473253                     Heaven for you(only for guy)  261338177
#
# ...

# %%
df2 = df[(df.price>min_thresold)&(df.price<max_thresold)]

# %%
df2.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df2
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df2.shape
# Out:
# (48183, 16)

# %%
df2.sample(7)
# Out:
#              id                                             name    host_id  \
# 46275  35179345         gorgeous apartment in financial district  115771987
# 3035    1785141                 Entire 1 Bedroom in Williamsburg    5481728
# 12030   9363966              2 BR available for summer rental!!!   48588586
# 20319  16237773  Quiet and beautiful apartment near central park   18104054
# 46625  35348968      Light filled private apartment in bed-stuy!   25127792
# 35954  28561906                  Spacious Modern Brooklyn Studio   14904449
# 11175   8652729          Beautiful room in a great location NYC!    4154037
#
#       host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 46275      Yuki           Manhattan  Financial District  40.70690  -74.00920
# 3035       Mike            Brooklyn        Williamsburg  40.70658  -73.96759
# 12030      Adam           Manhattan             Midtown  40.75511  -73.96825
# ...

# %%
df2.price.describe()
# Out:
# count    48183.000000
# mean       148.772036
# std        153.594795
# min         31.000000
# 25%         70.000000
# 50%        110.000000
# 75%        179.000000
# max       2999.000000
# Name: price, dtype: float64
